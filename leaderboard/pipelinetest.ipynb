# %%
import socket

# %%
# !pwd
# Out:
# /home/ubuntu/Project/leaderboard

# %%
import json
import socket
from pathlib import Path


# MACHINE_CONFIG_PATH = Path("/home/ubuntu/Project/machine.conf")
PROJECT_ROOT = Path(__file__).resolve().parent.parent
MACHINE_CONFIG_PATH = PROJECT_ROOT / "machine.config"

def load_machine_id() -> str:
    """Read the machine ID corresponding to the current hostname."""

    hostname = socket.gethostname()

    if not MACHINE_CONFIG_PATH.exists():
        raise FileNotFoundError(
            f"Machine configuration file not found: "
            f"{MACHINE_CONFIG_PATH}"
        )

    with MACHINE_CONFIG_PATH.open("r", encoding="utf-8") as file:
        machine_config = json.load(file)

    if hostname not in machine_config:
        available_hosts = ", ".join(machine_config.keys())
        raise KeyError(
            f"Hostname {hostname!r} is not configured in "
            f"{MACHINE_CONFIG_PATH}. "
            f"Configured hostnames: {available_hosts}"
        )

    machine_id = machine_config[hostname]

    if not isinstance(machine_id, int) or machine_id < 0:
        raise ValueError(
            f"Invalid machine ID for {hostname!r}: {machine_id!r}. "
            f"The machine ID must be a non-negative integer."
        )

    return str(machine_id).zfill(2)


HOSTNAME = socket.gethostname()
MACHINE = load_machine_id()

print(f"Current hostname: {HOSTNAME}")
print(f"Current machine ID: {MACHINE}")
# Out:
# Current hostname: ip-172-19-197-53
# Current machine ID: 01

# %%
HOSTNAME = socket.gethostname()

# %%
HOSTNAME
# Out:
# 'ip-172-19-197-53'

# %%
# !pip install pydrive2
# Out:
# Collecting pydrive2
#   Downloading PyDrive2-1.15.4-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 2.4 MB/s eta 0:00:00
# Collecting oauth2client>=4.0.0
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.7 MB/s eta 0:00:00
# Collecting pyOpenSSL>=19.1.0
#   Downloading pyopenssl-25.3.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=3.0 in /home/ubuntu/miniconda/envs/interfuser/lib/python3.7/site-packages (from pydrive2) (5.3)
# Collecting google-api-python-client>=1.12.5
#   Downloading google_api_python_client-2.198.0-py3-none-any.whl (15.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 83.0 MB/s eta 0:00:0000:0100:01
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5
#   Downloading google_api_core-2.29.0-py3-none-any.whl (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.9/173.9 kB 30.8 MB/s eta 0:00:00
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /home/ubuntu/miniconda/envs/interfuser/lib/python3.7/site-packages (from google-api-python-client>=1.12.5->pydrive2) (1.35.0)
# Collecting httplib2<1.0.0,>=0.19.0
#   Downloading httplib2-0.31.2-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 18.8 MB/s eta 0:00:00
# Collecting google-auth-httplib2<1.0.0,>=0.2.0
#   Downloading google_auth_httplib2-0.3.0-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: pyasn1>=0.1.7 in /home/ubuntu/miniconda/envs/interfuser/lib/python3.7/site-packages (from oauth2client>=4.0.0->pydrive2) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /home/ubuntu/miniconda/envs/interfuser/lib/python3.7/site-packages (from oauth2client>=4.0.0->pydrive2) (0.2.8)
# Requirement already satisfied: six>=1.6.1 in /home/ubuntu/miniconda/envs/interfuser/lib/python3.7/site-packages (from oauth2client>=4.0.0->pydrive2) (1.14.0)
# Requirement already satisfied: rsa>=3.1.4 in /home/ubuntu/miniconda/envs/interfuser/lib/python3.7/site-packages (from oauth2client>=4.0.0->pydrive2) (4.0)
# Collecting cryptography<47,>=45.0.7
#   Downloading cryptography-45.0.7-cp37-abi3-manylinux_2_34_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 77.0 MB/s eta 0:00:00ta 0:00:01
# Collecting cffi>=1.14
#   Downloading cffi-1.15.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (427 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.9/427.9 kB 56.9 MB/s eta 0:00:00
# Requirement already satisfied: importlib_metadata>=1.4 in /home/ubuntu/miniconda/envs/interfuser/lib/python3.7/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2) (1.6.0)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0
#   Downloading google_auth-2.45.0-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 34.3 MB/s eta 0:00:00
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5
#   Downloading protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 35.6 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /home/ubuntu/miniconda/envs/interfuser/lib/python3.7/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2) (2.23.0)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2
#   Downloading googleapis_common_protos-1.73.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 34.1 MB/s eta 0:00:00
# Collecting proto-plus<2.0.0,>=1.22.3
#   Downloading proto_plus-1.27.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /home/ubuntu/miniconda/envs/interfuser/lib/python3.7/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=1.12.5->pydrive2) (4.0.0)
# Collecting pyparsing<4,>=3.1
#   Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 15.0 MB/s eta 0:00:00
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /home/ubuntu/miniconda/envs/interfuser/lib/python3.7/site-packages (from importlib_metadata>=1.4->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/miniconda/envs/interfuser/lib/python3.7/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2) (2018.8.24)
# Requirement already satisfied: idna<3,>=2.5 in /home/ubuntu/miniconda/envs/interfuser/lib/python3.7/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ubuntu/miniconda/envs/interfuser/lib/python3.7/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2) (1.25.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/ubuntu/miniconda/envs/interfuser/lib/python3.7/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2) (3.0.4)
# Installing collected packages: uritemplate, pyparsing, pycparser, protobuf, proto-plus, httplib2, googleapis-common-protos, google-auth, cffi, oauth2client, google-auth-httplib2, google-api-core, cryptography, pyOpenSSL, google-api-python-client, pydrive2
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 2.4.6
#     Uninstalling pyparsing-2.4.6:
#       Successfully uninstalled pyparsing-2.4.6
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.11.3
#     Uninstalling protobuf-3.11.3:
#       Successfully uninstalled protobuf-3.11.3
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.35.0
#     Uninstalling google-auth-1.35.0:
#       Successfully uninstalled google-auth-1.35.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorboardx 2.6 requires protobuf<4,>=3.8.0, but you have protobuf 4.24.4 which is incompatible.
# tensorboard 2.1.1 requires google-auth<2,>=1.6.3, but you have google-auth 2.45.0 which is incompatible.
# Successfully installed cffi-1.15.1 cryptography-45.0.7 google-api-core-2.29.0 google-api-python-client-2.198.0 google-auth-2.45.0 google-auth-httplib2-0.3.0 googleapis-common-protos-1.73.0 httplib2-0.31.2 oauth2client-4.1.3 proto-plus-1.27.1 protobuf-4.24.4 pyOpenSSL-25.3.0 pycparser-2.21 pydrive2-1.15.4 pyparsing-3.1.4 uritemplate-4.1.1

# %%
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive

gauth = GoogleAuth()
gauth.LocalWebserverAuth()

drive = GoogleDrive(gauth)
# Out:
# Failed to start a local web server. Please check your firewall
# settings and locally running programs that may be blocking or
# using configured ports. Default ports are 8080 and 8090.
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-3-eb5bc0d1b755> in <module>
#       3
#       4 gauth = GoogleAuth()
# ----> 5 gauth.LocalWebserverAuth()
#       6
#       7 drive = GoogleDrive(gauth)
#
# ~/miniconda/envs/interfuser/lib/python3.7/site-packages/pydrive2/auth.py in _decorated(self, *args, **kwargs)
#     124             self.GetFlow()
#     125         if self.credentials is None:
# --> 126             code = decoratee(self, *args, **kwargs)
#     127             dirty = True
#     128         else:
#
# ~/miniconda/envs/interfuser/lib/python3.7/site-packages/pydrive2/auth.py in LocalWebserverAuth(self, host_name, port_numbers, launch_browser, bind_addr)
#     267             )
#     268             print("using configured ports. Default ports are 8080 and 8090.")
# --> 269             raise AuthenticationError()
#     270         self.flow.redirect_uri = oauth_callback
#     271         authorize_url = self.GetAuthUrl()
#
# AuthenticationError:

# %%
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive

# 第一次运行时会打开浏览器进行 Google 登录授权
gauth = GoogleAuth()
gauth.LocalWebserverAuth()

drive = GoogleDrive(gauth)

local_file = "result.csv"

google_file = drive.CreateFile({
    "title": "result.csv"
})

google_file.SetContentFile(local_file)
google_file.Upload()

print("上传成功")
print("Google Drive 文件 ID：", google_file["id"])
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=602297842813-c6p8l1cttnegvgd7flkbq497i23no815.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8090%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=online&response_type=code
#
# Authentication successful.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-178710882fc6> in <module>
#      14 })
#      15
# ---> 16 google_file.SetContentFile(local_file)
#      17 google_file.Upload()
#      18
#
# ~/miniconda/envs/interfuser/lib/python3.7/site-packages/pydrive2/files.py in SetContentFile(self, filename)
#     260         :type filename: str.
#     261         """
# --> 262         self.content = open(filename, "rb")
#     263         if self.get("id") is None:
#     264             if self.get("title") is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'result.csv'

# %%
from drive_upload import compress_and_upload

local_folder = '../data'
archive_name = "experiment_results"
machine_index=0

compress_and_upload(local_folder, archive_name, machine_index)
# Out:
# 正在压缩：/home/ubuntu/Project/data
# 压缩包路径：/home/ubuntu/Project/experiment_results.tar.gz
# 压缩完成，大小：11.41 MB
# 开始上传到：myDrive:machine_0
# 上传完成
# PosixPath('/home/ubuntu/Project/experiment_results.tar.gz')

# %%
"5".rjust(2,'0')
# Out:
# '05'

# %%
from drive_upload import upload_to_machine_folder
local_folder = '../data'
machine_index = 0
upload_to_machine_folder(local_folder, machine_index)
# Out:
# /home/ubuntu/miniconda/envs/interfuser/lib/python3.7/site-packages/oauth2client/_helpers.py:255: UserWarning: Cannot access ../upload_settings.json: No such file or directory
#   warnings.warn(_MISSING_FILE_MESSAGE.format(filename))
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=602297842813-c6p8l1cttnegvgd7flkbq497i23no815.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8090%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=online&response_type=code
#
# Authentication successful.
# 目标 Drive 文件夹：machine_0
# 本地文件夹：/home/ubuntu/Project/data
# 进入子文件夹：/home/ubuntu/Project/data/InterFuser
# 进入子文件夹：/home/ubuntu/Project/data/InterFuser/2026-07-08|10:04:56
# 跳过重复文件：/home/ubuntu/Project/data/InterFuser/2026-07-08|10:04:56/criterion.csv
# 跳过重复文件：/home/ubuntu/Project/data/InterFuser/2026-07-08|10:04:56/experiment_config.json
# 跳过重复文件：/home/ubuntu/Project/data/InterFuser/2026-07-08|10:04:56/fitness.csv
# 进入子文件夹：/home/ubuntu/Project/data/InterFuser/2026-07-08|10:04:56/routes_courve_07_08_10_05_19
# 跳过重复文件：/home/ubuntu/Project/data/InterFuser/2026-07-08|10:04:56/routes_courve_07_08_10_05_19/acc-v.png
# 跳过重复文件：/home/ubuntu/Project/data/InterFuser/2026-07-08|10:04:56/routes_courve_07_08_10_05_19/acc.npy
# 进入子文件夹：/home/ubuntu/Project/data/InterFuser/2026-07-08|10:04:56/routes_courve_07_08_10_05_19/bev
# 跳过重复文件：/home/ubuntu/Project/data/InterFuser/2026-07-08|10:04:56/routes_courve_07_08_10_05_19/control.csv
# 进入子文件夹：/home/ubuntu/Project/data/InterFuser/2026-07-08|10:04:56/routes_courve_07_08_10_05_19/meta
# 跳过重复文件：/home/ubuntu/Project/data/InterFuser/2026-07-08|10:04:56/routes_courve_07_08_10_05_19/ori_route.csv
# 跳过重复文件：/home/ubuntu/Project/data/InterFuser/2026-07-08|10:04:56/routes_courve_07_08_10_05_19/real_route.csv
# 跳过重复文件：/home/ubuntu/Project/data/InterFuser/2026-07-08|10:04:56/routes_courve_07_08_10_05_19/v.npy
# 进入子文件夹：/home/ubuntu/Project/data/InterFuser/2026-07-08|10:04:56/routes_courve_07_08_10_09_38
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-fdd85c1f4ce8> in <module>
#       2 local_folder = '../data'
#       3 machine_index = 0
# ----> 4 upload_to_machine_folder(local_folder, machine_index)
#
# ~/Project/leaderboard/drive_upload.py in upload_to_machine_folder(local_folder, machine_index)
#     229         drive=drive,
#     230         local_directory=local_path,
# --> 231         drive_parent_id=machine_folder_id,
#     232     )
#     233
#
# ~/Project/leaderboard/drive_upload.py in upload_directory_recursive(drive, local_directory, drive_parent_id)
#     194                 drive=drive,
#     195                 local_directory=local_item,
# --> 196                 drive_parent_id=child_drive_folder_id,
#     197             )
#     198
#
# ~/Project/leaderboard/drive_upload.py in upload_directory_recursive(drive, local_directory, drive_parent_id)
#     194                 drive=drive,
#     195                 local_directory=local_item,
# --> 196                 drive_parent_id=child_drive_folder_id,
#     197             )
#     198
#
# ~/Project/leaderboard/drive_upload.py in upload_directory_recursive(drive, local_directory, drive_parent_id)
#     194                 drive=drive,
#     195                 local_directory=local_item,
# --> 196                 drive_parent_id=child_drive_folder_id,
#     197             )
#     198
#
# ~/Project/leaderboard/drive_upload.py in upload_directory_recursive(drive, local_directory, drive_parent_id)
#     170     existing_names = get_existing_item_names(
#     171         drive=drive,
# --> 172         parent_id=drive_parent_id,
#     173     )
#     174
#
# ~/Project/leaderboard/drive_upload.py in get_existing_item_names(drive, parent_id)
#     122     )
#     123
# --> 124     items = drive.ListFile({"q": query}).GetList()
#     125
#     126     return {item["title"] for item in items}
#
# ~/miniconda/envs/interfuser/lib/python3.7/site-packages/pydrive2/apiattr.py in GetList(self)
#     164             self["maxResults"] = 1000
#     165             result = []
# --> 166             for x in self:
#     167                 result.extend(x)
#     168             del self["maxResults"]
#
# ~/miniconda/envs/interfuser/lib/python3.7/site-packages/pydrive2/apiattr.py in __next__(self)
#     148         if "pageToken" in self and self["pageToken"] is None:
#     149             raise StopIteration
# --> 150         result = self._GetList()
#     151         self["pageToken"] = self.metadata.get("nextPageToken")
#     152         return result
#
# ~/miniconda/envs/interfuser/lib/python3.7/site-packages/pydrive2/auth.py in _decorated(self, *args, **kwargs)
#      82             self.http = self.auth.thread_local.http
#      83
# ---> 84         return decoratee(self, *args, **kwargs)
#      85
#      86     return _decorated
#
# ~/miniconda/envs/interfuser/lib/python3.7/site-packages/pydrive2/files.py in _GetList(self)
#      84                 self.auth.service.files()
#      85                 .list(**dict(self))
# ---> 86                 .execute(http=self.http)
#      87             )
#      88         except errors.HttpError as error:
#
# ~/miniconda/envs/interfuser/lib/python3.7/site-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#     132         return positional_wrapper
#
# ~/miniconda/envs/interfuser/lib/python3.7/site-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     930             method=str(self.method),
#     931             body=self.body,
# --> 932             headers=self.headers,
#     933         )
#     934
#
# ~/miniconda/envs/interfuser/lib/python3.7/site-packages/googleapiclient/http.py in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     189         try:
#     190             exception = None
# --> 191             resp, content = http.request(uri, method, *args, **kwargs)
#     192         # Retry on SSL errors and socket timeout errors.
#     193         except _ssl_SSLError as ssl_error:
#
# ~/miniconda/envs/interfuser/lib/python3.7/site-packages/oauth2client/transport.py in new_request(uri, method, body, headers, redirections, connection_type)
#     173         resp, content = request(orig_request_method, uri, method, body,
#     174                                 clean_headers(headers),
# --> 175                                 redirections, connection_type)
#     176
#     177         # A stored token may expire between the time it is retrieved and
#
# ~/miniconda/envs/interfuser/lib/python3.7/site-packages/oauth2client/transport.py in request(http, uri, method, body, headers, redirections, connection_type)
#     280     return http_callable(uri, method=method, body=body, headers=headers,
#     281                          redirections=redirections,
# --> 282                          connection_type=connection_type)
#     283
#     284
#
# ~/miniconda/envs/interfuser/lib/python3.7/site-packages/httplib2/__init__.py in request(self, uri, method, body, headers, redirections, connection_type)
#    1726                 else:
#    1727                     (response, content) = self._request(
# -> 1728                         conn, authority, uri, request_uri, method, body, headers, redirections, cachekey,
#    1729                     )
#    1730         except Exception as e:
#
# ~/miniconda/envs/interfuser/lib/python3.7/site-packages/httplib2/__init__.py in _request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1445             auth.request(method, request_uri, headers, body)
#    1446
# -> 1447         (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#    1448
#    1449         if auth:
#
# ~/miniconda/envs/interfuser/lib/python3.7/site-packages/httplib2/__init__.py in _conn_request(self, conn, request_uri, method, body, headers)
#    1397                 pass
#    1398             try:
# -> 1399                 response = conn.getresponse()
#    1400             except (http.client.BadStatusLine, http.client.ResponseNotReady):
#    1401                 # If we get a BadStatusLine on the first try then that means
#
# ~/miniconda/envs/interfuser/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# ~/miniconda/envs/interfuser/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~/miniconda/envs/interfuser/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~/miniconda/envs/interfuser/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/miniconda/envs/interfuser/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/miniconda/envs/interfuser/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
